# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import time
import datetime

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

pd.set_option('display.max_columns', 30)

# %%
df = pd.read_csv("data/df_post_EDA.csv", index_col=0)
df.head()
# Out:
#    user_ID  chapter_ID relative_renewal_date   P  A  L  M  S  RGI  RGO  RRI  \
# 0        0          31            2016-04-01  33  0  0  1  0   21    7   33
# 1        2          18            2017-05-01  33  2  2  0  0    6   17   11
# 2        2          18            2018-05-01  35  1  0  0  2    6   24   19
# 3        2          18            2019-05-01  36  0  0  0  1    9    8   23
# 4        2          18            2020-05-01  33  1  0  0  3   10   13   19
#
#    RRO  V  1-2-1   TYFCB  CEU  year_of_membership  chapter_size  \
# 0   32  1     37  129784   45                   0            32
# 1   22  1     26    9285    1                   0            34
# 2   36  1     20    7263   10                   1            21
# 3   19  3     28    1860   31                   2            22
# 4   47  4     30    6668   16                   3            26
#
#    chapter_retention_rate  chapter_growth_rate  seat_popularity_rate  \
# 0                0.315789             1.421053              0.076923
# 1                0.718750             1.093750              0.266667
# 2                0.424242             0.636364              0.210526
# 3                0.739130             1.217391              0.263158
# 4                0.760000             1.120000              0.277778
#
#    total_meetings  wont_renew
# 0              34           0
# 1              37           0
# 2              38           0
# 3              37           0
# 4              37           0

# %% [markdown]
# ### Drop & split

# %%
df.drop(["user_ID", "relative_renewal_date"], axis=1, inplace=True)

# %%
df["P_by_A"] = df["P"] / (df["A"] + 1)
df["P_by_M"] = df["P"] / (df["M"] + 1)
df["P_by_S"] = df["P"] / (df["S"] + 1)
df["P_by_total"] = df["P"] / df["total_meetings"]
df["A_by_total"] = df["A"] / df["total_meetings"]
df["M_by_total"] = df["M"] / df["total_meetings"]

df["P_tim_retention"] = df["P"] * df["chapter_retention_rate"]
df["P_tim_growth"] = df["P"] * df["chapter_growth_rate"]
df["P_tim_popularity"] = df["P"] * df["seat_popularity_rate"]
df["P_tim_V"] = df["P"] * df["V"]
df["P2_tim_V"] = df["P"]**2 * df["V"]
df["P_tim_TYFCB"] = df["P"] * df["TYFCB"]

df["year_tim_retention"] = df["year_of_membership"] * df["chapter_retention_rate"]

df["P2"] = df["P"]**2

columns_list = df.columns.tolist()
columns_list.remove("wont_renew")

columns_list+= ["wont_renew"]
df = df[columns_list]

# %% [markdown]
# ### Final pick

# %%
logreg_10_features = pd.read_csv("feature_selection/pick_10_features_logreg.csv", index_col=0)
logreg_10_features = logreg_10_features["feature_name"].tolist()

dt_10_features = pd.read_csv("feature_selection/pick_10_features_dt.csv", index_col=0)
dt_10_features = dt_10_features["feature_name"].tolist()

rf_10_features = pd.read_csv("feature_selection/pick_10_features_rf.csv", index_col=0)
rf_10_features = rf_10_features["feature_name"].tolist()

ada_10_features = pd.read_csv("feature_selection/pick_10_features_ada.csv", index_col=0)
ada_10_features = ada_10_features["feature_name"].tolist()

xgb_10_features = pd.read_csv("feature_selection/pick_10_features_xgb.csv", index_col=0)
xgb_10_features = xgb_10_features["feature_name"].tolist()

catboost_10_features = pd.read_csv("feature_selection/pick_10_features_catboost.csv", index_col=0)
catboost_10_features = catboost_10_features["feature_name"].tolist()

# %% [markdown]
# # Model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from catboost import CatBoostClassifier, Pool
import xgboost as xgb

import scikitplot as skplt

from sklearn.calibration import CalibratedClassifierCV
from sklearn.decomposition import PCA
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score, roc_curve, auc, classification_report
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score

from imblearn.under_sampling import EditedNearestNeighbours, TomekLinks, NeighbourhoodCleaningRule
from imblearn.over_sampling import SMOTE, ADASYN
from collections import Counter

# %%
df_scores = pd.DataFrame(columns=["training_time [s]", "accuracy", "precision", "recall", "f1", "auc"])

labels = []
errors_uncalibrated = []
errors_isotonic = []
errors_sigmoid = []

# %% [markdown]
# ## 1. Logistic Regression

# %%
X = df.drop(["wont_renew", "chapter_ID"], axis=1).copy()
y = df["wont_renew"].copy()

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=710)

under_sampler = TomekLinks()
X_resampled, y_resampled = under_sampler.fit_resample(X_train, y_train)

scaler = StandardScaler()
scaler.fit(X_resampled)
X_resampled = pd.DataFrame(scaler.transform(X_resampled), columns=X.columns)
X_test = pd.DataFrame(scaler.transform(X_test), columns=X.columns)

# %%
logreg = LogisticRegression(max_iter=5000)

X_resampled_logreg = X_resampled[logreg_10_features]
X_test_logreg = X_test[logreg_10_features]

logreg_grid = {}
logreg_grid["C"] = [0.001, 0.003, 0.01, 0.03, 0.1, 0.3, 1, 3, 10, 30, 100]

logreg_cv = GridSearchCV(logreg, logreg_grid, scoring="roc_auc", n_jobs=-1, cv=3)

start = time.time()
logreg_cv.fit(X_resampled_logreg, y_resampled)
end = time.time()
print(f"Elapsed time: {(end - start):.2f} seconds")
print(logreg_cv.best_params_)

y_pred = logreg_cv.predict(X_test_logreg)
y_proba = logreg_cv.predict_proba(X_test_logreg)

df_scores.loc["logistic_regression"] = [round(end - start, 2),
                                        accuracy_score(y_test, y_pred),
                                        precision_score(y_test, y_pred),
                                        recall_score(y_test, y_pred),
                                        f1_score(y_test, y_pred),
                                        roc_auc_score(y_test, y_proba[:,1])]
# Out:
# Elapsed time: 2.16 seconds
# {'C': 0.001}

# %%
fig = skplt.metrics.plot_calibration_curve(y_test, [y_proba], figsize=(10,6), clf_names=["Logreg"])
plt.tight_layout()
plt.savefig('plots/step8_logreg_uncalibrated.png', dpi=300, bbox_inches='tight')
plt.show()

squared_error_uncalibrated = sum((fig.get_lines()[1].get_xdata() - fig.get_lines()[1].get_ydata())**2)

labels.append("LogReg")
errors_uncalibrated.append(squared_error_uncalibrated)

# %%
test_model = LogisticRegression(max_iter=5000, **logreg_cv.best_params_)
calibrated_clf = CalibratedClassifierCV(base_estimator=test_model, cv=3, method="sigmoid")

calibrated_clf.fit(X_resampled_logreg, y_resampled)

y_pred = calibrated_clf.predict(X_test_logreg)
y_proba = calibrated_clf.predict_proba(X_test_logreg)

fig = skplt.metrics.plot_calibration_curve(y_test, [y_proba], figsize=(12,7), clf_names=["Logreg"])

squared_error_sigmoid = sum((fig.get_lines()[1].get_xdata() - fig.get_lines()[1].get_ydata())**2)
errors_sigmoid.append(squared_error_sigmoid)
plt.show()

df_scores.loc["logistic_regression_platt"] = [round(end - start, 2),
                                        accuracy_score(y_test, y_pred),
                                        precision_score(y_test, y_pred),
                                        recall_score(y_test, y_pred),
                                        f1_score(y_test, y_pred),
                                        roc_auc_score(y_test, y_proba[:,1])]

# %%
test_model = LogisticRegression(max_iter=5000, **logreg_cv.best_params_)
calibrated_clf = CalibratedClassifierCV(base_estimator=test_model, cv=3, method="isotonic")

calibrated_clf.fit(X_resampled_logreg, y_resampled)

y_pred = calibrated_clf.predict(X_test_logreg)
y_proba = calibrated_clf.predict_proba(X_test_logreg)

fig = skplt.metrics.plot_calibration_curve(y_test, [y_proba], figsize=(12,7), clf_names=["Logreg"])

squared_error_isotonic = sum((fig.get_lines()[1].get_xdata() - fig.get_lines()[1].get_ydata())**2)
errors_isotonic.append(squared_error_isotonic)
plt.show()

df_scores.loc["logistic_regression_isotonic"] = [round(end - start, 2),
                                        accuracy_score(y_test, y_pred),
                                        precision_score(y_test, y_pred),
                                        recall_score(y_test, y_pred),
                                        f1_score(y_test, y_pred),
                                        roc_auc_score(y_test, y_proba[:,1])]

# %% [markdown]
# ## 2. Naive Bayes

# %%
X = df.drop(["wont_renew", "chapter_ID"], axis=1).copy()
y = df["wont_renew"].copy()

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=710)

under_sampler = TomekLinks()
X_resampled, y_resampled = under_sampler.fit_resample(X_train, y_train)

scaler = StandardScaler()
scaler.fit(X_resampled)
X_resampled = pd.DataFrame(scaler.transform(X_resampled), columns=X.columns)
X_test = pd.DataFrame(scaler.transform(X_test), columns=X.columns)

pca = PCA(n_components=10)
pca.fit(X)
X_resampled = pd.DataFrame(pca.transform(X_resampled))
X_test = pd.DataFrame(pca.transform(X_test))
# print(pca.explained_variance_ratio_)

# %%
naive_bayes = GaussianNB()

start = time.time()
naive_bayes.fit(X_resampled, y_resampled)
end = time.time()
print(f"Elapsed time: {(end - start):.2f} seconds")

y_pred = naive_bayes.predict(X_test)
y_proba = naive_bayes.predict_proba(X_test)

df_scores.loc["naive_bayes"] = [round(end - start, 2),
                                        accuracy_score(y_test, y_pred),
                                        precision_score(y_test, y_pred),
                                        recall_score(y_test, y_pred),
                                        f1_score(y_test, y_pred),
                                        roc_auc_score(y_test, y_proba[:,1])]
# Out:
# Elapsed time: 0.00 seconds

# %%
fig = skplt.metrics.plot_calibration_curve(y_test, [y_proba], figsize=(10,6), clf_names=["Naive Bayes"])
plt.tight_layout()
plt.savefig('plots/step8_NB_uncalibrated.png', dpi=300, bbox_inches='tight')
plt.show()

squared_error_uncalibrated = sum((fig.get_lines()[1].get_xdata() - fig.get_lines()[1].get_ydata())**2)

labels.append("NB")
errors_uncalibrated.append(squared_error_uncalibrated)

# %%
test_model = GaussianNB()
calibrated_clf = CalibratedClassifierCV(base_estimator=test_model, cv=3, method="sigmoid")

calibrated_clf.fit(X_resampled, y_resampled)

y_pred = calibrated_clf.predict(X_test)
y_proba = calibrated_clf.predict_proba(X_test)

fig = skplt.metrics.plot_calibration_curve(y_test, [y_proba], figsize=(12,7), clf_names=["Naive Bayes"])

squared_error_sigmoid = sum((fig.get_lines()[1].get_xdata() - fig.get_lines()[1].get_ydata())**2)
errors_sigmoid.append(squared_error_sigmoid)
plt.show()

df_scores.loc["naive_bayes_platt"] = [round(end - start, 2),
                                        accuracy_score(y_test, y_pred),
                                        precision_score(y_test, y_pred),
                                        recall_score(y_test, y_pred),
                                        f1_score(y_test, y_pred),
                                        roc_auc_score(y_test, y_proba[:,1])]
# Out:
# C:\Users\davem\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
test_model = GaussianNB()
calibrated_clf = CalibratedClassifierCV(base_estimator=test_model, cv=3, method="isotonic")

calibrated_clf.fit(X_resampled, y_resampled)

y_pred = calibrated_clf.predict(X_test)
y_proba = calibrated_clf.predict_proba(X_test)

fig = skplt.metrics.plot_calibration_curve(y_test, [y_proba], figsize=(12,7), clf_names=["Naive Bayes"])

squared_error_isotonic = sum((fig.get_lines()[1].get_xdata() - fig.get_lines()[1].get_ydata())**2)
errors_isotonic.append(squared_error_isotonic)
plt.show()

df_scores.loc["naive_bayes_isotonic"] = [round(end - start, 2),
                                        accuracy_score(y_test, y_pred),
                                        precision_score(y_test, y_pred),
                                        recall_score(y_test, y_pred),
                                        f1_score(y_test, y_pred),
                                        roc_auc_score(y_test, y_proba[:,1])]

# %% [markdown]
# ## 3. K-neighbors classifier

# %%
X = df.drop(["wont_renew", "chapter_ID"], axis=1).copy()
y = df["wont_renew"].copy()

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=710)

under_sampler = TomekLinks()
X_resampled, y_resampled = under_sampler.fit_resample(X_train, y_train)

scaler = StandardScaler()
scaler.fit(X_resampled)
X_resampled = pd.DataFrame(scaler.transform(X_resampled), columns=X.columns)
X_test = pd.DataFrame(scaler.transform(X_test), columns=X.columns)

pca = PCA(n_components=10)
pca.fit(X)
X_resampled = pd.DataFrame(pca.transform(X_resampled))
X_test = pd.DataFrame(pca.transform(X_test))
# print(pca.explained_variance_ratio_)

# %%
knn = KNeighborsClassifier()

knn_grid = {}
knn_grid["n_neighbors"] = [x for x in range(3,20,2)]
knn_grid["weights"] = ["uniform", "distance"]
knn_grid["leaf_size"] = [x for x in range(5,55,5)]

knn_cv = GridSearchCV(knn, knn_grid, scoring="roc_auc", n_jobs=-1, cv=3)

start = time.time()
knn_cv.fit(X_resampled, y_resampled)
end = time.time()
print(f"Elapsed time: {(end - start):.2f} seconds")
print(knn_cv.best_params_)

y_pred = knn_cv.predict(X_test)
y_proba = knn_cv.predict_proba(X_test)

df_scores.loc["knn"] = [round(end - start, 2),
                                        accuracy_score(y_test, y_pred),
                                        precision_score(y_test, y_pred),
                                        recall_score(y_test, y_pred),
                                        f1_score(y_test, y_pred),
                                        roc_auc_score(y_test, y_proba[:,1])]
# Out:
# Elapsed time: 1.86 seconds
# {'leaf_size': 5, 'n_neighbors': 19, 'weights': 'distance'}

# %%
fig = skplt.metrics.plot_calibration_curve(y_test, [y_proba], figsize=(10,6), clf_names=["KNN"])
plt.tight_layout()
plt.savefig('plots/step8_KNN_uncalibrated.png', dpi=300, bbox_inches='tight')
plt.show()

squared_error_uncalibrated = sum((fig.get_lines()[1].get_xdata() - fig.get_lines()[1].get_ydata())**2)

labels.append("KNN")
errors_uncalibrated.append(squared_error_uncalibrated)

# %%
test_model = KNeighborsClassifier(**knn_cv.best_params_)
calibrated_clf = CalibratedClassifierCV(base_estimator=test_model, cv=3, method="sigmoid")

calibrated_clf.fit(X_resampled, y_resampled)

y_pred = calibrated_clf.predict(X_test)
y_proba = calibrated_clf.predict_proba(X_test)

fig = skplt.metrics.plot_calibration_curve(y_test, [y_proba], figsize=(12,7), clf_names=["KNN"])

squared_error_sigmoid = sum((fig.get_lines()[1].get_xdata() - fig.get_lines()[1].get_ydata())**2)
errors_sigmoid.append(squared_error_sigmoid)
plt.show()

df_scores.loc["knn_platt"] = [round(end - start, 2),
                                        accuracy_score(y_test, y_pred),
                                        precision_score(y_test, y_pred),
                                        recall_score(y_test, y_pred),
                                        f1_score(y_test, y_pred),
                                        roc_auc_score(y_test, y_proba[:,1])]

# %%
test_model = KNeighborsClassifier(**knn_cv.best_params_)
calibrated_clf = CalibratedClassifierCV(base_estimator=test_model, cv=3, method="isotonic")

calibrated_clf.fit(X_resampled, y_resampled)

y_pred = calibrated_clf.predict(X_test)
y_proba = calibrated_clf.predict_proba(X_test)

fig = skplt.metrics.plot_calibration_curve(y_test, [y_proba], figsize=(12,7), clf_names=["KNN"])

squared_error_isotonic = sum((fig.get_lines()[1].get_xdata() - fig.get_lines()[1].get_ydata())**2)
errors_isotonic.append(squared_error_isotonic)
plt.show()

df_scores.loc["knn_isotonic"] = [round(end - start, 2),
                                        accuracy_score(y_test, y_pred),
                                        precision_score(y_test, y_pred),
                                        recall_score(y_test, y_pred),
                                        f1_score(y_test, y_pred),
                                        roc_auc_score(y_test, y_proba[:,1])]

# %% [markdown]
# ## 4. Decision Tree

# %%
X = df.drop(["wont_renew", "chapter_ID"], axis=1).copy()
y = df["wont_renew"].copy()

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=710)

under_sampler = TomekLinks()
X_resampled, y_resampled = under_sampler.fit_resample(X_train, y_train)

scaler = StandardScaler()
scaler.fit(X_resampled)
X_resampled = pd.DataFrame(scaler.transform(X_resampled), columns=X.columns)
X_test = pd.DataFrame(scaler.transform(X_test), columns=X.columns)

# %%
dt = DecisionTreeClassifier()

X_resampled_dt = X_resampled[dt_10_features]
X_test_dt = X_test[dt_10_features]

dt_grid = {}
dt_grid["max_depth"] = [x for x in range(2, 51, 2)]
dt_grid["min_samples_split"] = [x for x in range(2, 11, 2)]
dt_grid["min_samples_leaf"] = [x for x in range(1, 8, 1)]

dt_cv = GridSearchCV(dt, dt_grid, scoring="roc_auc", n_jobs=-1, cv=3, verbose=2)

start = time.time()
dt_cv.fit(X_resampled_dt, y_resampled)
end = time.time()
print(f"Elapsed time: {(end - start):.2f} seconds")
print(dt_cv.best_params_)

y_pred = dt_cv.predict(X_test_dt)
y_proba = dt_cv.predict_proba(X_test_dt)

df_scores.loc["decision_tree"] = [round(end - start, 2),
                                        accuracy_score(y_test, y_pred),
                                        precision_score(y_test, y_pred),
                                        recall_score(y_test, y_pred),
                                        f1_score(y_test, y_pred),
                                        roc_auc_score(y_test, y_proba[:,1])]
# Out:
# Fitting 3 folds for each of 875 candidates, totalling 2625 fits
# Elapsed time: 4.33 seconds
# {'max_depth': 2, 'min_samples_leaf': 1, 'min_samples_split': 2}

# %%
fig = skplt.metrics.plot_calibration_curve(y_test, [y_proba], figsize=(10,6), clf_names=["DT"])
plt.tight_layout()
plt.savefig('plots/step8_DT_uncalibrated.png', dpi=300, bbox_inches='tight')
plt.show()

squared_error_uncalibrated = sum((fig.get_lines()[1].get_xdata() - fig.get_lines()[1].get_ydata())**2)

labels.append("DT")
errors_uncalibrated.append(squared_error_uncalibrated)

# %%
test_model = DecisionTreeClassifier(**dt_cv.best_params_)
calibrated_clf = CalibratedClassifierCV(base_estimator=test_model, cv=3, method="sigmoid")

calibrated_clf.fit(X_resampled_dt, y_resampled)

y_pred = calibrated_clf.predict(X_test_dt)
y_proba = calibrated_clf.predict_proba(X_test_dt)

fig = skplt.metrics.plot_calibration_curve(y_test, [y_proba], figsize=(12,7), clf_names=["DT"])

squared_error_sigmoid = sum((fig.get_lines()[1].get_xdata() - fig.get_lines()[1].get_ydata())**2)
errors_sigmoid.append(squared_error_sigmoid)
plt.show()

df_scores.loc["decision_tree_platt"] = [round(end - start, 2),
                                        accuracy_score(y_test, y_pred),
                                        precision_score(y_test, y_pred),
                                        recall_score(y_test, y_pred),
                                        f1_score(y_test, y_pred),
                                        roc_auc_score(y_test, y_proba[:,1])]

# %%
test_model = DecisionTreeClassifier(**dt_cv.best_params_)
calibrated_clf = CalibratedClassifierCV(base_estimator=test_model, cv=3, method="isotonic")

calibrated_clf.fit(X_resampled_dt, y_resampled)

y_pred = calibrated_clf.predict(X_test_dt)
y_proba = calibrated_clf.predict_proba(X_test_dt)

fig = skplt.metrics.plot_calibration_curve(y_test, [y_proba], figsize=(12,7), clf_names=["DT"])

squared_error_isotonic = sum((fig.get_lines()[1].get_xdata() - fig.get_lines()[1].get_ydata())**2)
errors_isotonic.append(squared_error_isotonic)
plt.show()

df_scores.loc["decision_tree_isotonic"] = [round(end - start, 2),
                                        accuracy_score(y_test, y_pred),
                                        precision_score(y_test, y_pred),
                                        recall_score(y_test, y_pred),
                                        f1_score(y_test, y_pred),
                                        roc_auc_score(y_test, y_proba[:,1])]

# %% [markdown]
# ## 5. Random Forest

# %%
X = df.drop(["wont_renew", "chapter_ID"], axis=1).copy()
y = df["wont_renew"].copy()

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=710)

under_sampler = TomekLinks()
X_resampled, y_resampled = under_sampler.fit_resample(X_train, y_train)

scaler = StandardScaler()
scaler.fit(X_resampled)
X_resampled = pd.DataFrame(scaler.transform(X_resampled), columns=X.columns)
X_test = pd.DataFrame(scaler.transform(X_test), columns=X.columns)

# %%
rf = RandomForestClassifier()

X_resampled_rf = X_resampled[rf_10_features]
X_test_rf = X_test[rf_10_features]

rf_grid = {}
rf_grid["n_estimators"] = [50, 100, 200, 400]
rf_grid["max_depth"] = [x for x in range(2, 10, 2)]
rf_grid["min_samples_split"] = [x for x in range(2, 7, 2)]
rf_grid["min_samples_leaf"] = [x for x in range(1, 6, 1)]

rf_cv = GridSearchCV(rf, rf_grid, scoring="roc_auc", n_jobs=-1, cv=3, verbose=2)

start = time.time()
rf_cv.fit(X_resampled_rf, y_resampled)
end = time.time()
print(f"Elapsed time: {(end - start):.2f} seconds")
print(rf_cv.best_params_)

y_pred = rf_cv.predict(X_test_rf)
y_proba = rf_cv.predict_proba(X_test_rf)

df_scores.loc["random_forest"] = [round(end - start, 2),
                                        accuracy_score(y_test, y_pred),
                                        precision_score(y_test, y_pred),
                                        recall_score(y_test, y_pred),
                                        f1_score(y_test, y_pred),
                                        roc_auc_score(y_test, y_proba[:,1])]
# Out:
# Fitting 3 folds for each of 240 candidates, totalling 720 fits
# Elapsed time: 55.40 seconds
# {'max_depth': 4, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}

# %%
fig = skplt.metrics.plot_calibration_curve(y_test, [y_proba], figsize=(10,6), clf_names=["RF"])
plt.tight_layout()
plt.savefig('plots/step8_RF_uncalibrated.png', dpi=300, bbox_inches='tight')
plt.show()

squared_error_uncalibrated = sum((fig.get_lines()[1].get_xdata() - fig.get_lines()[1].get_ydata())**2)

labels.append("RF")
errors_uncalibrated.append(squared_error_uncalibrated)

# %%
test_model = RandomForestClassifier(**rf_cv.best_params_)
calibrated_clf = CalibratedClassifierCV(base_estimator=test_model, cv=3, method="sigmoid")

calibrated_clf.fit(X_resampled_rf, y_resampled)

y_pred = calibrated_clf.predict(X_test_rf)
y_proba = calibrated_clf.predict_proba(X_test_rf)

fig = skplt.metrics.plot_calibration_curve(y_test, [y_proba], figsize=(12,7), clf_names=["RF"])

squared_error_sigmoid = sum((fig.get_lines()[1].get_xdata() - fig.get_lines()[1].get_ydata())**2)
errors_sigmoid.append(squared_error_sigmoid)
plt.show()

df_scores.loc["random_forest_platt"] = [round(end - start, 2),
                                        accuracy_score(y_test, y_pred),
                                        precision_score(y_test, y_pred),
                                        recall_score(y_test, y_pred),
                                        f1_score(y_test, y_pred),
                                        roc_auc_score(y_test, y_proba[:,1])]

# %%
test_model = RandomForestClassifier(**rf_cv.best_params_)
calibrated_clf = CalibratedClassifierCV(base_estimator=test_model, cv=3, method="isotonic")

calibrated_clf.fit(X_resampled_rf, y_resampled)

y_pred = calibrated_clf.predict(X_test_rf)
y_proba = calibrated_clf.predict_proba(X_test_rf)

fig = skplt.metrics.plot_calibration_curve(y_test, [y_proba], figsize=(12,7), clf_names=["RF"])

squared_error_isotonic = sum((fig.get_lines()[1].get_xdata() - fig.get_lines()[1].get_ydata())**2)
errors_isotonic.append(squared_error_isotonic)
plt.show()

df_scores.loc["random_forest_isotonic"] = [round(end - start, 2),
                                        accuracy_score(y_test, y_pred),
                                        precision_score(y_test, y_pred),
                                        recall_score(y_test, y_pred),
                                        f1_score(y_test, y_pred),
                                        roc_auc_score(y_test, y_proba[:,1])]

# %% [markdown]
# ## 6. AdaBoost

# %%
X = df.drop(["wont_renew", "chapter_ID"], axis=1).copy()
y = df["wont_renew"].copy()

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=710)

under_sampler = TomekLinks()
X_resampled, y_resampled = under_sampler.fit_resample(X_train, y_train)

scaler = StandardScaler()
scaler.fit(X_resampled)
X_resampled = pd.DataFrame(scaler.transform(X_resampled), columns=X.columns)
X_test = pd.DataFrame(scaler.transform(X_test), columns=X.columns)

# %%
ada = AdaBoostClassifier()

X_resampled_ada = X_resampled[ada_10_features]
X_test_ada = X_test[ada_10_features]

ada_grid = {}
ada_grid["n_estimators"] = [50, 100, 200, 400]
ada_grid["learning_rate"] = [0.03, 0.1, 0.3, 1]

ada_cv = GridSearchCV(ada, ada_grid, scoring="roc_auc", n_jobs=-1, cv=3, verbose=2)

start = time.time()
ada_cv.fit(X_resampled_ada, y_resampled)
end = time.time()
print(f"Elapsed time: {(end - start):.2f} seconds")
print(ada_cv.best_params_)

y_pred = ada_cv.predict(X_test_ada)
y_proba = ada_cv.predict_proba(X_test_ada)

df_scores.loc["AdaBoost"] = [round(end - start, 2),
                                        accuracy_score(y_test, y_pred),
                                        precision_score(y_test, y_pred),
                                        recall_score(y_test, y_pred),
                                        f1_score(y_test, y_pred),
                                        roc_auc_score(y_test, y_proba[:,1])]
# Out:
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Elapsed time: 4.78 seconds
# {'learning_rate': 0.1, 'n_estimators': 200}

# %%
fig = skplt.metrics.plot_calibration_curve(y_test, [y_proba], figsize=(10,6), clf_names=["ada"])
plt.tight_layout()
plt.savefig('plots/step8_ada_uncalibrated.png', dpi=300, bbox_inches='tight')
plt.show()

squared_error_uncalibrated = sum((fig.get_lines()[1].get_xdata() - fig.get_lines()[1].get_ydata())**2)

labels.append("AdaBoost")
errors_uncalibrated.append(squared_error_uncalibrated)

# %%
test_model = AdaBoostClassifier(**ada_cv.best_params_)
calibrated_clf = CalibratedClassifierCV(base_estimator=test_model, cv=3, method="sigmoid")

calibrated_clf.fit(X_resampled_ada, y_resampled)

y_pred = calibrated_clf.predict(X_test_ada)
y_proba = calibrated_clf.predict_proba(X_test_ada)

fig = skplt.metrics.plot_calibration_curve(y_test, [y_proba], figsize=(12,7), clf_names=["ada"])

squared_error_sigmoid = sum((fig.get_lines()[1].get_xdata() - fig.get_lines()[1].get_ydata())**2)
errors_sigmoid.append(squared_error_sigmoid)
plt.show()

df_scores.loc["AdaBoost_platt"] = [round(end - start, 2),
                                        accuracy_score(y_test, y_pred),
                                        precision_score(y_test, y_pred),
                                        recall_score(y_test, y_pred),
                                        f1_score(y_test, y_pred),
                                        roc_auc_score(y_test, y_proba[:,1])]

# %%
test_model = AdaBoostClassifier(**ada_cv.best_params_)
calibrated_clf = CalibratedClassifierCV(base_estimator=test_model, cv=3, method="isotonic")

calibrated_clf.fit(X_resampled_ada, y_resampled)

y_pred = calibrated_clf.predict(X_test_ada)
y_proba = calibrated_clf.predict_proba(X_test_ada)

fig = skplt.metrics.plot_calibration_curve(y_test, [y_proba], figsize=(12,7), clf_names=["ada"])

squared_error_isotonic = sum((fig.get_lines()[1].get_xdata() - fig.get_lines()[1].get_ydata())**2)
errors_isotonic.append(squared_error_isotonic)
plt.show()

df_scores.loc["AdaBoost_isotonic"] = [round(end - start, 2),
                                        accuracy_score(y_test, y_pred),
                                        precision_score(y_test, y_pred),
                                        recall_score(y_test, y_pred),
                                        f1_score(y_test, y_pred),
                                        roc_auc_score(y_test, y_proba[:,1])]

# %% [markdown]
# ## 7. XGBoost

# %%
X = df.drop(["wont_renew", "chapter_ID"], axis=1).copy()
y = df["wont_renew"].copy()

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=710)

under_sampler = TomekLinks()
X_resampled, y_resampled = under_sampler.fit_resample(X_train, y_train)

scaler = StandardScaler()
scaler.fit(X_resampled)
X_resampled = pd.DataFrame(scaler.transform(X_resampled), columns=X.columns)
X_test = pd.DataFrame(scaler.transform(X_test), columns=X.columns)

# %%
xg = xgb.XGBClassifier(objective='binary:logistic', eval_metric="auc", random_state=42, use_label_encoder=False)

X_resampled_xgb = X_resampled[xgb_10_features]
X_test_xgb = X_test[xgb_10_features]

xg_grid = {}
xg_grid["n_estimators"] = [50, 100, 200, 400]
xg_grid["colsample_bytree"] = [0.1, 0.3, 0.5, 0.8]
xg_grid["learning_rate"] = [0.03, 0.1, 0.3, 1]
xg_grid["max_depth"] = [x for x in range(2, 11, 1)]
xg_grid["alpha"] = [0.1, 0.3, 1, 3, 10]

xg_cv = GridSearchCV(xg, xg_grid, scoring="roc_auc", n_jobs=-1, cv=3, verbose=2)

start = time.time()
xg_cv.fit(X_resampled_xgb, y_resampled)
end = time.time()
print(f"Elapsed time: {(end - start):.2f} seconds")
print(xg_cv.best_params_)

y_pred = xg_cv.predict(X_test_xgb)
y_proba = xg_cv.predict_proba(X_test_xgb)

df_scores.loc["XGBoost"] = [round(end - start, 2),
                                        accuracy_score(y_test, y_pred),
                                        precision_score(y_test, y_pred),
                                        recall_score(y_test, y_pred),
                                        f1_score(y_test, y_pred),
                                        roc_auc_score(y_test, y_proba[:,1])]
# Out:
# Fitting 3 folds for each of 2880 candidates, totalling 8640 fits
# Elapsed time: 299.89 seconds
# {'alpha': 3, 'colsample_bytree': 0.1, 'learning_rate': 0.03, 'max_depth': 2, 'n_estimators': 50}

# %%
fig = skplt.metrics.plot_calibration_curve(y_test, [y_proba], figsize=(10,6), clf_names=["xgb"])
plt.tight_layout()
plt.savefig('plots/step8_xgb_uncalibrated.png', dpi=300, bbox_inches='tight')
plt.show()

squared_error_uncalibrated = sum((fig.get_lines()[1].get_xdata() - fig.get_lines()[1].get_ydata())**2)

labels.append("XGBoost")
errors_uncalibrated.append(squared_error_uncalibrated)

# %%
test_model = xgb.XGBClassifier(objective='binary:logistic', eval_metric="auc", random_state=42, use_label_encoder=False, **xg_cv.best_params_)
calibrated_clf = CalibratedClassifierCV(base_estimator=test_model, cv=3, method="sigmoid")

calibrated_clf.fit(X_resampled_xgb, y_resampled)

y_pred = calibrated_clf.predict(X_test_xgb)
y_proba = calibrated_clf.predict_proba(X_test_xgb)

fig = skplt.metrics.plot_calibration_curve(y_test, [y_proba], figsize=(12,7), clf_names=["xgb"])

squared_error_sigmoid = sum((fig.get_lines()[1].get_xdata() - fig.get_lines()[1].get_ydata())**2)
errors_sigmoid.append(squared_error_sigmoid)
plt.savefig('plots/step8_xgb_platt.png', dpi=300, bbox_inches='tight')
plt.show()

df_scores.loc["XGBoost_platt"] = [round(end - start, 2),
                                        accuracy_score(y_test, y_pred),
                                        precision_score(y_test, y_pred),
                                        recall_score(y_test, y_pred),
                                        f1_score(y_test, y_pred),
                                        roc_auc_score(y_test, y_proba[:,1])]

# %%
test_model = xgb.XGBClassifier(objective='binary:logistic', eval_metric="auc", random_state=42, use_label_encoder=False, **xg_cv.best_params_)
calibrated_clf = CalibratedClassifierCV(base_estimator=test_model, cv=3, method="isotonic")

calibrated_clf.fit(X_resampled_xgb, y_resampled)

y_pred = calibrated_clf.predict(X_test_xgb)
y_proba = calibrated_clf.predict_proba(X_test_xgb)

fig = skplt.metrics.plot_calibration_curve(y_test, [y_proba], figsize=(12,7), clf_names=["xgb"])

squared_error_isotonic = sum((fig.get_lines()[1].get_xdata() - fig.get_lines()[1].get_ydata())**2)
errors_isotonic.append(squared_error_isotonic)
plt.savefig('plots/step8_xgb_isotonic.png', dpi=300, bbox_inches='tight')
plt.show()

df_scores.loc["XGBoost_isotonic"] = [round(end - start, 2),
                                        accuracy_score(y_test, y_pred),
                                        precision_score(y_test, y_pred),
                                        recall_score(y_test, y_pred),
                                        f1_score(y_test, y_pred),
                                        roc_auc_score(y_test, y_proba[:,1])]

# %% [markdown]
# ## 8. CatBoost

# %%
X = df.drop(["wont_renew"], axis=1).copy()
y = df["wont_renew"].copy()

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=710)

cb = CatBoostClassifier(early_stopping_rounds=20, eval_metric="AUC", verbose=0, cat_features=["chapter_ID"])

X_train_cat = X_train[catboost_10_features]
X_test_cat = X_test[catboost_10_features]

cb_grid = {}
cb_grid["iterations"] = [50, 100, 200, 400]
cb_grid["learning_rate"] = [0.03, 0.1, 0.3, 1]
cb_grid['l2_leaf_reg'] = [1, 3, 5, 7, 9]
cb_grid["depth"] = [4, 6, 8, 10]

start = time.time()
grid_search_result = cb.grid_search(cb_grid, X=X_train_cat, y=y_train, plot=False)
end = time.time()
print(f"Elapsed time: {(end - start):.2f} seconds")
print(grid_search_result["params"])

y_pred = cb.predict(X_test_cat)
y_proba = cb.predict_proba(X_test_cat)
df_scores.loc["CatBoost"] = [round(end - start, 2),
                                        accuracy_score(y_test, y_pred),
                                        precision_score(y_test, y_pred),
                                        recall_score(y_test, y_pred),
                                        f1_score(y_test, y_pred),
                                        roc_auc_score(y_test, y_proba[:,1])]
# Out:
# bestTest = 0.6937004904
# bestIteration = 46
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 0:	loss: 0.6937005	best: 0.6937005 (0)	total: 1.2s	remaining: 6m 24s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6889098453
# bestIteration = 15
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 1:	loss: 0.6889098	best: 0.6937005 (0)	total: 1.92s	remaining: 5m 5s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6961523953
# bestIteration = 25
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 2:	loss: 0.6961524	best: 0.6961524 (2)	total: 2.9s	remaining: 5m 7s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.667125613
# bestIteration = 2
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 3:	loss: 0.6671256	best: 0.6961524 (2)	total: 3.35s	remaining: 4m 24s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6961146737
# bestIteration = 4
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 4:	loss: 0.6961147	best: 0.6961524 (2)	total: 3.85s	remaining: 4m 2s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.7042814032
# bestIteration = 5
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 5:	loss: 0.7042814	best: 0.7042814 (5)	total: 4.37s	remaining: 3m 48s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.679253112
# bestIteration = 4
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 6:	loss: 0.6792531	best: 0.7042814 (5)	total: 4.84s	remaining: 3m 36s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6448321388
# bestIteration = 2
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 7:	loss: 0.6448321	best: 0.7042814 (5)	total: 5.25s	remaining: 3m 24s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6858543946
# bestIteration = 26
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 8:	loss: 0.6858544	best: 0.7042814 (5)	total: 6.2s	remaining: 3m 34s
#
# bestTest = 0.6973217654
# bestIteration = 46
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 9:	loss: 0.6973218	best: 0.7042814 (5)	total: 7.35s	remaining: 3m 47s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6797812146
# bestIteration = 4
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 10:	loss: 0.6797812	best: 0.7042814 (5)	total: 7.86s	remaining: 3m 40s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6721614485
# bestIteration = 28
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 11:	loss: 0.6721614	best: 0.7042814 (5)	total: 9.09s	remaining: 3m 53s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.7017917767
# bestIteration = 13
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 12:	loss: 0.7017918	best: 0.7042814 (5)	total: 9.99s	remaining: 3m 56s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6934552999
# bestIteration = 6
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 13:	loss: 0.6934553	best: 0.7042814 (5)	total: 10.6s	remaining: 3m 51s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6821388155
# bestIteration = 14
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 14:	loss: 0.6821388	best: 0.7042814 (5)	total: 11.4s	remaining: 3m 51s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6650320634
# bestIteration = 21
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 15:	loss: 0.6650321	best: 0.7042814 (5)	total: 12.4s	remaining: 3m 55s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6907582045
# bestIteration = 28
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 16:	loss: 0.6907582	best: 0.7042814 (5)	total: 13.7s	remaining: 4m 3s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6887212373
# bestIteration = 6
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 17:	loss: 0.6887212	best: 0.7042814 (5)	total: 14.3s	remaining: 4m
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.679158808
# bestIteration = 4
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 18:	loss: 0.6791588	best: 0.7042814 (5)	total: 14.9s	remaining: 3m 55s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6669181441
# bestIteration = 4
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 19:	loss: 0.6669181	best: 0.7042814 (5)	total: 15.4s	remaining: 3m 51s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6937004904
# bestIteration = 46
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 20:	loss: 0.6937005	best: 0.7042814 (5)	total: 16.8s	remaining: 3m 59s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6889098453
# bestIteration = 15
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 21:	loss: 0.6889098	best: 0.7042814 (5)	total: 17.7s	remaining: 3m 59s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6961523953
# bestIteration = 25
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 22:	loss: 0.6961524	best: 0.7042814 (5)	total: 18.7s	remaining: 4m 1s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.667125613
# bestIteration = 2
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 23:	loss: 0.6671256	best: 0.7042814 (5)	total: 19.1s	remaining: 3m 56s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6961146737
# bestIteration = 4
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 24:	loss: 0.6961147	best: 0.7042814 (5)	total: 19.8s	remaining: 3m 53s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.7042814032
# bestIteration = 5
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 25:	loss: 0.7042814	best: 0.7042814 (5)	total: 20.3s	remaining: 3m 49s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.679253112
# bestIteration = 4
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 26:	loss: 0.6792531	best: 0.7042814 (5)	total: 20.9s	remaining: 3m 46s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6448321388
# bestIteration = 2
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 27:	loss: 0.6448321	best: 0.7042814 (5)	total: 21.4s	remaining: 3m 42s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6858543946
# bestIteration = 26
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 28:	loss: 0.6858544	best: 0.7042814 (5)	total: 22.3s	remaining: 3m 44s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6973217654
# bestIteration = 46
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 29:	loss: 0.6973218	best: 0.7042814 (5)	total: 23.7s	remaining: 3m 49s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6797812146
# bestIteration = 4
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 30:	loss: 0.6797812	best: 0.7042814 (5)	total: 24.2s	remaining: 3m 45s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6721614485
# bestIteration = 28
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 31:	loss: 0.6721614	best: 0.7042814 (5)	total: 25s	remaining: 3m 45s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.7017917767
# bestIteration = 13
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 32:	loss: 0.7017918	best: 0.7042814 (5)	total: 25.8s	remaining: 3m 44s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6934552999
# bestIteration = 6
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 33:	loss: 0.6934553	best: 0.7042814 (5)	total: 26.4s	remaining: 3m 41s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6821388155
# bestIteration = 14
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 34:	loss: 0.6821388	best: 0.7042814 (5)	total: 27.1s	remaining: 3m 40s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6650320634
# bestIteration = 21
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 35:	loss: 0.6650321	best: 0.7042814 (5)	total: 28s	remaining: 3m 40s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6907582045
# bestIteration = 28
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 36:	loss: 0.6907582	best: 0.7042814 (5)	total: 28.9s	remaining: 3m 40s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6887212373
# bestIteration = 6
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 37:	loss: 0.6887212	best: 0.7042814 (5)	total: 29.4s	remaining: 3m 38s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.679158808
# bestIteration = 4
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 38:	loss: 0.6791588	best: 0.7042814 (5)	total: 29.9s	remaining: 3m 35s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6669181441
# bestIteration = 4
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 39:	loss: 0.6669181	best: 0.7042814 (5)	total: 30.3s	remaining: 3m 32s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6947566956
# bestIteration = 34
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 40:	loss: 0.6947567	best: 0.7042814 (5)	total: 31.8s	remaining: 3m 36s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6974349302
# bestIteration = 16
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 41:	loss: 0.6974349	best: 0.7042814 (5)	total: 32.6s	remaining: 3m 35s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6924179555
# bestIteration = 19
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 42:	loss: 0.6924180	best: 0.7042814 (5)	total: 33.7s	remaining: 3m 36s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6678611845
# bestIteration = 8
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 43:	loss: 0.6678612	best: 0.7042814 (5)	total: 34.3s	remaining: 3m 35s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.7063749528
# bestIteration = 30
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 44:	loss: 0.7063750	best: 0.7063750 (44)	total: 35.4s	remaining: 3m 36s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.7089400226
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 45:	loss: 0.7089400	best: 0.7089400 (45)	total: 36.1s	remaining: 3m 34s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.7094304036
# bestIteration = 7
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 46:	loss: 0.7094304	best: 0.7094304 (46)	total: 36.8s	remaining: 3m 33s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6834402112
# bestIteration = 6
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 47:	loss: 0.6834402	best: 0.7094304 (46)	total: 37.4s	remaining: 3m 32s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6984534138
# bestIteration = 6
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 48:	loss: 0.6984534	best: 0.7094304 (46)	total: 38.1s	remaining: 3m 30s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.7041870992
# bestIteration = 7
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 49:	loss: 0.7041871	best: 0.7094304 (46)	total: 38.8s	remaining: 3m 29s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.7075254621
# bestIteration = 3
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 50:	loss: 0.7075255	best: 0.7094304 (46)	total: 39.3s	remaining: 3m 27s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6819313467
# bestIteration = 2
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 51:	loss: 0.6819313	best: 0.7094304 (46)	total: 39.8s	remaining: 3m 24s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6989815164
# bestIteration = 6
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 52:	loss: 0.6989815	best: 0.7094304 (46)	total: 40.3s	remaining: 3m 23s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.7045077329
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 53:	loss: 0.7045077	best: 0.7094304 (46)	total: 41s	remaining: 3m 22s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.7072614108
# bestIteration = 3
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 54:	loss: 0.7072614	best: 0.7094304 (46)	total: 41.6s	remaining: 3m 20s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6870614862
# bestIteration = 3
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 55:	loss: 0.6870615	best: 0.7094304 (46)	total: 42.3s	remaining: 3m 19s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.699019238
# bestIteration = 6
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 56:	loss: 0.6990192	best: 0.7094304 (46)	total: 43s	remaining: 3m 18s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.7010184836
# bestIteration = 7
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 57:	loss: 0.7010185	best: 0.7094304 (46)	total: 43.5s	remaining: 3m 16s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.7069219163
# bestIteration = 3
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 58:	loss: 0.7069219	best: 0.7094304 (46)	total: 43.9s	remaining: 3m 14s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6860430026
# bestIteration = 14
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 59:	loss: 0.6860430	best: 0.7094304 (46)	total: 44.5s	remaining: 3m 12s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6947566956
# bestIteration = 34
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 60:	loss: 0.6947567	best: 0.7094304 (46)	total: 45.6s	remaining: 3m 13s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6974349302
# bestIteration = 16
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 61:	loss: 0.6974349	best: 0.7094304 (46)	total: 46.3s	remaining: 3m 12s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6924179555
# bestIteration = 19
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 62:	loss: 0.6924180	best: 0.7094304 (46)	total: 47s	remaining: 3m 11s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6678611845
# bestIteration = 8
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 63:	loss: 0.6678612	best: 0.7094304 (46)	total: 47.5s	remaining: 3m 10s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.7063749528
# bestIteration = 30
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 64:	loss: 0.7063750	best: 0.7094304 (46)	total: 48.5s	remaining: 3m 10s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.7089400226
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 65:	loss: 0.7089400	best: 0.7094304 (46)	total: 49s	remaining: 3m 8s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.7094304036
# bestIteration = 7
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 66:	loss: 0.7094304	best: 0.7094304 (46)	total: 49.5s	remaining: 3m 7s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6834402112
# bestIteration = 6
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 67:	loss: 0.6834402	best: 0.7094304 (46)	total: 50.1s	remaining: 3m 5s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6984534138
# bestIteration = 6
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 68:	loss: 0.6984534	best: 0.7094304 (46)	total: 50.6s	remaining: 3m 4s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.7041870992
# bestIteration = 7
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 69:	loss: 0.7041871	best: 0.7094304 (46)	total: 51.1s	remaining: 3m 2s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.7075254621
# bestIteration = 3
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 70:	loss: 0.7075255	best: 0.7094304 (46)	total: 51.6s	remaining: 3m 1s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6819313467
# bestIteration = 2
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 71:	loss: 0.6819313	best: 0.7094304 (46)	total: 52.1s	remaining: 2m 59s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6989815164
# bestIteration = 6
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 72:	loss: 0.6989815	best: 0.7094304 (46)	total: 52.6s	remaining: 2m 57s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.7045077329
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 73:	loss: 0.7045077	best: 0.7094304 (46)	total: 53.1s	remaining: 2m 56s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.7072614108
# bestIteration = 3
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 74:	loss: 0.7072614	best: 0.7094304 (46)	total: 53.6s	remaining: 2m 55s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6870614862
# bestIteration = 3
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 75:	loss: 0.6870615	best: 0.7094304 (46)	total: 54s	remaining: 2m 53s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.699019238
# bestIteration = 6
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 76:	loss: 0.6990192	best: 0.7094304 (46)	total: 54.6s	remaining: 2m 52s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.7010184836
# bestIteration = 7
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 77:	loss: 0.7010185	best: 0.7094304 (46)	total: 55.1s	remaining: 2m 50s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.7069219163
# bestIteration = 3
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 78:	loss: 0.7069219	best: 0.7094304 (46)	total: 55.6s	remaining: 2m 49s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6860430026
# bestIteration = 14
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 79:	loss: 0.6860430	best: 0.7094304 (46)	total: 56.2s	remaining: 2m 48s
#
# bestTest = 0.6892116183
# bestIteration = 44
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 80:	loss: 0.6892116	best: 0.7094304 (46)	total: 57.5s	remaining: 2m 49s
#
# bestTest = 0.6908713693
# bestIteration = 35
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 81:	loss: 0.6908714	best: 0.7094304 (46)	total: 58.8s	remaining: 2m 50s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6764617126
# bestIteration = 19
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 82:	loss: 0.6764617	best: 0.7094304 (46)	total: 59.8s	remaining: 2m 50s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.655771407
# bestIteration = 3
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 83:	loss: 0.6557714	best: 0.7094304 (46)	total: 1m	remaining: 2m 49s
#
# bestTest = 0.6867597133
# bestIteration = 44
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 84:	loss: 0.6867597	best: 0.7094304 (46)	total: 1m 1s	remaining: 2m 50s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6815918521
# bestIteration = 8
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 85:	loss: 0.6815919	best: 0.7094304 (46)	total: 1m 2s	remaining: 2m 51s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6804224821
# bestIteration = 7
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 86:	loss: 0.6804225	best: 0.7094304 (46)	total: 1m 3s	remaining: 2m 50s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6528668427
# bestIteration = 5
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 87:	loss: 0.6528668	best: 0.7094304 (46)	total: 1m 4s	remaining: 2m 50s
#
# bestTest = 0.6829875519
# bestIteration = 44
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 88:	loss: 0.6829876	best: 0.7094304 (46)	total: 1m 6s	remaining: 2m 51s
#
# bestTest = 0.6961523953
# bestIteration = 48
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 89:	loss: 0.6961524	best: 0.7094304 (46)	total: 1m 7s	remaining: 2m 53s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6806488118
# bestIteration = 7
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 90:	loss: 0.6806488	best: 0.7094304 (46)	total: 1m 8s	remaining: 2m 53s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6523387401
# bestIteration = 1
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 91:	loss: 0.6523387	best: 0.7094304 (46)	total: 1m 9s	remaining: 2m 52s
#
# bestTest = 0.6877781969
# bestIteration = 44
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 92:	loss: 0.6877782	best: 0.7094304 (46)	total: 1m 11s	remaining: 2m 53s
#
# bestTest = 0.6927951716
# bestIteration = 32
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 93:	loss: 0.6927952	best: 0.7094304 (46)	total: 1m 12s	remaining: 2m 54s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6715956243
# bestIteration = 11
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 94:	loss: 0.6715956	best: 0.7094304 (46)	total: 1m 13s	remaining: 2m 54s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6611090155
# bestIteration = 1
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 95:	loss: 0.6611090	best: 0.7094304 (46)	total: 1m 14s	remaining: 2m 53s
#
# bestTest = 0.6898528857
# bestIteration = 46
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 96:	loss: 0.6898529	best: 0.7094304 (46)	total: 1m 16s	remaining: 2m 54s
#
# bestTest = 0.6877404753
# bestIteration = 31
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 97:	loss: 0.6877405	best: 0.7094304 (46)	total: 1m 17s	remaining: 2m 55s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6627687665
# bestIteration = 22
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 98:	loss: 0.6627688	best: 0.7094304 (46)	total: 1m 18s	remaining: 2m 56s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6519049415
# bestIteration = 2
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 99:	loss: 0.6519049	best: 0.7094304 (46)	total: 1m 19s	remaining: 2m 55s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6892116183
# bestIteration = 44
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 100:	loss: 0.6892116	best: 0.7094304 (46)	total: 1m 21s	remaining: 2m 56s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6908713693
# bestIteration = 35
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 101:	loss: 0.6908714	best: 0.7094304 (46)	total: 1m 22s	remaining: 2m 57s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6764617126
# bestIteration = 19
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 102:	loss: 0.6764617	best: 0.7094304 (46)	total: 1m 24s	remaining: 2m 57s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.655771407
# bestIteration = 3
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 103:	loss: 0.6557714	best: 0.7094304 (46)	total: 1m 24s	remaining: 2m 56s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6872500943
# bestIteration = 55
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 104:	loss: 0.6872501	best: 0.7094304 (46)	total: 1m 26s	remaining: 2m 57s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6815918521
# bestIteration = 8
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 105:	loss: 0.6815919	best: 0.7094304 (46)	total: 1m 27s	remaining: 2m 57s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6804224821
# bestIteration = 7
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 106:	loss: 0.6804225	best: 0.7094304 (46)	total: 1m 28s	remaining: 2m 56s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6528668427
# bestIteration = 5
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 107:	loss: 0.6528668	best: 0.7094304 (46)	total: 1m 29s	remaining: 2m 54s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6843832516
# bestIteration = 64
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 108:	loss: 0.6843833	best: 0.7094304 (46)	total: 1m 31s	remaining: 2m 57s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6961523953
# bestIteration = 48
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 109:	loss: 0.6961524	best: 0.7094304 (46)	total: 1m 33s	remaining: 2m 58s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6806488118
# bestIteration = 7
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 110:	loss: 0.6806488	best: 0.7094304 (46)	total: 1m 34s	remaining: 2m 58s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6523387401
# bestIteration = 1
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 111:	loss: 0.6523387	best: 0.7094304 (46)	total: 1m 35s	remaining: 2m 56s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6908713693
# bestIteration = 63
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 112:	loss: 0.6908714	best: 0.7094304 (46)	total: 1m 37s	remaining: 2m 59s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6927951716
# bestIteration = 32
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 113:	loss: 0.6927952	best: 0.7094304 (46)	total: 1m 39s	remaining: 2m 59s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6715956243
# bestIteration = 11
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 114:	loss: 0.6715956	best: 0.7094304 (46)	total: 1m 40s	remaining: 2m 59s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6611090155
# bestIteration = 1
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 115:	loss: 0.6611090	best: 0.7094304 (46)	total: 1m 41s	remaining: 2m 57s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6900037722
# bestIteration = 53
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 116:	loss: 0.6900038	best: 0.7094304 (46)	total: 1m 43s	remaining: 2m 59s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6877404753
# bestIteration = 31
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 117:	loss: 0.6877405	best: 0.7094304 (46)	total: 1m 44s	remaining: 2m 59s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6627687665
# bestIteration = 22
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 118:	loss: 0.6627688	best: 0.7094304 (46)	total: 1m 46s	remaining: 2m 59s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6519049415
# bestIteration = 2
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 119:	loss: 0.6519049	best: 0.7094304 (46)	total: 1m 47s	remaining: 2m 58s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6909468125
# bestIteration = 55
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 120:	loss: 0.6909468	best: 0.7094304 (46)	total: 1m 49s	remaining: 3m
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.7032817805
# bestIteration = 14
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 121:	loss: 0.7032818	best: 0.7094304 (46)	total: 1m 51s	remaining: 3m
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6840437571
# bestIteration = 24
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 122:	loss: 0.6840438	best: 0.7094304 (46)	total: 1m 52s	remaining: 3m
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6392304791
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 123:	loss: 0.6392305	best: 0.7094304 (46)	total: 1m 53s	remaining: 2m 59s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6946435307
# bestIteration = 114
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 124:	loss: 0.6946435	best: 0.7094304 (46)	total: 1m 58s	remaining: 3m 5s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6956620143
# bestIteration = 15
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 125:	loss: 0.6956620	best: 0.7094304 (46)	total: 2m	remaining: 3m 4s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6898151641
# bestIteration = 18
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 126:	loss: 0.6898152	best: 0.7094304 (46)	total: 2m 1s	remaining: 3m 4s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6368351565
# bestIteration = 5
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 127:	loss: 0.6368352	best: 0.7094304 (46)	total: 2m 2s	remaining: 3m 3s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6906827612
# bestIteration = 29
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 128:	loss: 0.6906828	best: 0.7094304 (46)	total: 2m 4s	remaining: 3m 4s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.695397963
# bestIteration = 25
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 129:	loss: 0.6953980	best: 0.7094304 (46)	total: 2m 6s	remaining: 3m 4s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6943417578
# bestIteration = 27
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 130:	loss: 0.6943418	best: 0.7094304 (46)	total: 2m 7s	remaining: 3m 4s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6813278008
# bestIteration = 2
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 131:	loss: 0.6813278	best: 0.7094304 (46)	total: 2m 8s	remaining: 3m 2s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6955111279
# bestIteration = 39
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 132:	loss: 0.6955111	best: 0.7094304 (46)	total: 2m 10s	remaining: 3m 3s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6966427763
# bestIteration = 14
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 133:	loss: 0.6966428	best: 0.7094304 (46)	total: 2m 11s	remaining: 3m 2s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6897774425
# bestIteration = 6
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 134:	loss: 0.6897774	best: 0.7094304 (46)	total: 2m 12s	remaining: 3m 1s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6873443983
# bestIteration = 4
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 135:	loss: 0.6873444	best: 0.7094304 (46)	total: 2m 13s	remaining: 3m
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6937004904
# bestIteration = 18
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 136:	loss: 0.6937005	best: 0.7094304 (46)	total: 2m 14s	remaining: 2m 59s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6920030177
# bestIteration = 34
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 137:	loss: 0.6920030	best: 0.7094304 (46)	total: 2m 16s	remaining: 3m
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6801207092
# bestIteration = 3
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 138:	loss: 0.6801207	best: 0.7094304 (46)	total: 2m 17s	remaining: 2m 59s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6608449642
# bestIteration = 5
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 139:	loss: 0.6608450	best: 0.7094304 (46)	total: 2m 18s	remaining: 2m 57s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6909468125
# bestIteration = 55
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 140:	loss: 0.6909468	best: 0.7094304 (46)	total: 2m 20s	remaining: 2m 58s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.7032817805
# bestIteration = 14
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 141:	loss: 0.7032818	best: 0.7094304 (46)	total: 2m 21s	remaining: 2m 57s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6840437571
# bestIteration = 24
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 142:	loss: 0.6840438	best: 0.7094304 (46)	total: 2m 23s	remaining: 2m 57s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6392304791
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 143:	loss: 0.6392305	best: 0.7094304 (46)	total: 2m 24s	remaining: 2m 56s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6946435307
# bestIteration = 114
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 144:	loss: 0.6946435	best: 0.7094304 (46)	total: 2m 28s	remaining: 2m 59s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6956620143
# bestIteration = 15
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 145:	loss: 0.6956620	best: 0.7094304 (46)	total: 2m 29s	remaining: 2m 57s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6898151641
# bestIteration = 18
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 146:	loss: 0.6898152	best: 0.7094304 (46)	total: 2m 30s	remaining: 2m 56s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6368351565
# bestIteration = 5
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 147:	loss: 0.6368352	best: 0.7094304 (46)	total: 2m 31s	remaining: 2m 55s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6906827612
# bestIteration = 29
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 148:	loss: 0.6906828	best: 0.7094304 (46)	total: 2m 32s	remaining: 2m 54s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.695397963
# bestIteration = 25
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 149:	loss: 0.6953980	best: 0.7094304 (46)	total: 2m 33s	remaining: 2m 54s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6943417578
# bestIteration = 27
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 150:	loss: 0.6943418	best: 0.7094304 (46)	total: 2m 34s	remaining: 2m 53s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6813278008
# bestIteration = 2
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 151:	loss: 0.6813278	best: 0.7094304 (46)	total: 2m 35s	remaining: 2m 51s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6955111279
# bestIteration = 39
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 152:	loss: 0.6955111	best: 0.7094304 (46)	total: 2m 37s	remaining: 2m 51s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6966427763
# bestIteration = 14
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 153:	loss: 0.6966428	best: 0.7094304 (46)	total: 2m 38s	remaining: 2m 50s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6897774425
# bestIteration = 6
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 154:	loss: 0.6897774	best: 0.7094304 (46)	total: 2m 38s	remaining: 2m 49s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6873443983
# bestIteration = 4
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 155:	loss: 0.6873444	best: 0.7094304 (46)	total: 2m 39s	remaining: 2m 47s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6937004904
# bestIteration = 18
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 156:	loss: 0.6937005	best: 0.7094304 (46)	total: 2m 40s	remaining: 2m 46s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6920030177
# bestIteration = 34
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 157:	loss: 0.6920030	best: 0.7094304 (46)	total: 2m 41s	remaining: 2m 46s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6801207092
# bestIteration = 3
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 158:	loss: 0.6801207	best: 0.7094304 (46)	total: 2m 42s	remaining: 2m 44s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6608449642
# bestIteration = 5
#
# ...
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.71565447
# bestIteration = 7
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 269:	loss: 0.7156545	best: 0.7345719 (242)	total: 5m 36s	remaining: 1m 2s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.7139192757
# bestIteration = 12
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 270:	loss: 0.7139193	best: 0.7345719 (242)	total: 5m 37s	remaining: 1m 1s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6847793286
# bestIteration = 0
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 271:	loss: 0.6847793	best: 0.7345719 (242)	total: 5m 39s	remaining: 59.8s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.7117314221
# bestIteration = 7
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 272:	loss: 0.7117314	best: 0.7345719 (242)	total: 5m 40s	remaining: 58.6s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.7075443229
# bestIteration = 24
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 273:	loss: 0.7075443	best: 0.7345719 (242)	total: 5m 42s	remaining: 57.6s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6908713693
# bestIteration = 30
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 274:	loss: 0.6908714	best: 0.7345719 (242)	total: 5m 45s	remaining: 56.6s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6443040362
# bestIteration = 1
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 275:	loss: 0.6443040	best: 0.7345719 (242)	total: 5m 46s	remaining: 55.3s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.7076197661
# bestIteration = 17
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 276:	loss: 0.7076198	best: 0.7345719 (242)	total: 5m 48s	remaining: 54.2s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.7033949453
# bestIteration = 7
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 277:	loss: 0.7033949	best: 0.7345719 (242)	total: 5m 50s	remaining: 53s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6944549227
# bestIteration = 10
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 278:	loss: 0.6944549	best: 0.7345719 (242)	total: 5m 52s	remaining: 51.7s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6952847982
# bestIteration = 38
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 279:	loss: 0.6952848	best: 0.7345719 (242)	total: 5m 55s	remaining: 50.8s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.7041870992
# bestIteration = 40
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 280:	loss: 0.7041871	best: 0.7345719 (242)	total: 5m 58s	remaining: 49.8s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6867597133
# bestIteration = 6
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 281:	loss: 0.6867597	best: 0.7345719 (242)	total: 5m 59s	remaining: 48.5s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6768389287
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 282:	loss: 0.6768389	best: 0.7345719 (242)	total: 6m 1s	remaining: 47.3s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6526027914
# bestIteration = 2
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 283:	loss: 0.6526028	best: 0.7345719 (242)	total: 6m 2s	remaining: 46s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6927197284
# bestIteration = 6
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 284:	loss: 0.6927197	best: 0.7345719 (242)	total: 6m 4s	remaining: 44.7s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.7044888721
# bestIteration = 11
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 285:	loss: 0.7044889	best: 0.7345719 (242)	total: 6m 5s	remaining: 43.5s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6570350811
# bestIteration = 19
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 286:	loss: 0.6570351	best: 0.7345719 (242)	total: 6m 8s	remaining: 42.3s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6862693323
# bestIteration = 8
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 287:	loss: 0.6862693	best: 0.7345719 (242)	total: 6m 9s	remaining: 41.1s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6841192003
# bestIteration = 5
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 288:	loss: 0.6841192	best: 0.7345719 (242)	total: 6m 11s	remaining: 39.8s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6962278386
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 289:	loss: 0.6962278	best: 0.7345719 (242)	total: 6m 12s	remaining: 38.6s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6902301018
# bestIteration = 16
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 290:	loss: 0.6902301	best: 0.7345719 (242)	total: 6m 14s	remaining: 37.3s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6736137307
# bestIteration = 3
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 291:	loss: 0.6736137	best: 0.7345719 (242)	total: 6m 16s	remaining: 36.1s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6943794794
# bestIteration = 8
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 292:	loss: 0.6943795	best: 0.7345719 (242)	total: 6m 17s	remaining: 34.8s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6949830253
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 293:	loss: 0.6949830	best: 0.7345719 (242)	total: 6m 19s	remaining: 33.5s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.673972086
# bestIteration = 15
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 294:	loss: 0.6739721	best: 0.7345719 (242)	total: 6m 21s	remaining: 32.3s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6572991324
# bestIteration = 3
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 295:	loss: 0.6572991	best: 0.7345719 (242)	total: 6m 22s	remaining: 31s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6979630328
# bestIteration = 11
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 296:	loss: 0.6979630	best: 0.7345719 (242)	total: 6m 24s	remaining: 29.7s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6915126367
# bestIteration = 50
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 297:	loss: 0.6915126	best: 0.7345719 (242)	total: 6m 27s	remaining: 28.6s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6886080724
# bestIteration = 19
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 298:	loss: 0.6886081	best: 0.7345719 (242)	total: 6m 29s	remaining: 27.4s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6719351188
# bestIteration = 4
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 299:	loss: 0.6719351	best: 0.7345719 (242)	total: 6m 31s	remaining: 26.1s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.7041870992
# bestIteration = 40
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 300:	loss: 0.7041871	best: 0.7345719 (242)	total: 6m 34s	remaining: 24.9s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6867597133
# bestIteration = 6
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 301:	loss: 0.6867597	best: 0.7345719 (242)	total: 6m 35s	remaining: 23.6s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6768389287
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 302:	loss: 0.6768389	best: 0.7345719 (242)	total: 6m 37s	remaining: 22.3s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6526027914
# bestIteration = 2
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 303:	loss: 0.6526028	best: 0.7345719 (242)	total: 6m 38s	remaining: 21s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6927197284
# bestIteration = 6
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 304:	loss: 0.6927197	best: 0.7345719 (242)	total: 6m 40s	remaining: 19.7s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.7044888721
# bestIteration = 11
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 305:	loss: 0.7044889	best: 0.7345719 (242)	total: 6m 41s	remaining: 18.4s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6570350811
# bestIteration = 19
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 306:	loss: 0.6570351	best: 0.7345719 (242)	total: 6m 44s	remaining: 17.1s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6862693323
# bestIteration = 8
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 307:	loss: 0.6862693	best: 0.7345719 (242)	total: 6m 45s	remaining: 15.8s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6841192003
# bestIteration = 5
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 308:	loss: 0.6841192	best: 0.7345719 (242)	total: 6m 46s	remaining: 14.5s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6962278386
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 309:	loss: 0.6962278	best: 0.7345719 (242)	total: 6m 48s	remaining: 13.2s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6902301018
# bestIteration = 16
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 310:	loss: 0.6902301	best: 0.7345719 (242)	total: 6m 50s	remaining: 11.9s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6736137307
# bestIteration = 3
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 311:	loss: 0.6736137	best: 0.7345719 (242)	total: 6m 51s	remaining: 10.6s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6943794794
# bestIteration = 8
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 312:	loss: 0.6943795	best: 0.7345719 (242)	total: 6m 53s	remaining: 9.25s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6949830253
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 313:	loss: 0.6949830	best: 0.7345719 (242)	total: 6m 55s	remaining: 7.93s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.673972086
# bestIteration = 15
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 314:	loss: 0.6739721	best: 0.7345719 (242)	total: 6m 56s	remaining: 6.62s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6572991324
# bestIteration = 3
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 315:	loss: 0.6572991	best: 0.7345719 (242)	total: 6m 58s	remaining: 5.29s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6979630328
# bestIteration = 11
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 316:	loss: 0.6979630	best: 0.7345719 (242)	total: 6m 59s	remaining: 3.97s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6915126367
# bestIteration = 50
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 317:	loss: 0.6915126	best: 0.7345719 (242)	total: 7m 3s	remaining: 2.66s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6886080724
# bestIteration = 19
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 318:	loss: 0.6886081	best: 0.7345719 (242)	total: 7m 5s	remaining: 1.33s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6719351188
# bestIteration = 4
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 319:	loss: 0.6719351	best: 0.7345719 (242)	total: 7m 6s	remaining: 0us
# Estimating final quality...
# Training on fold [0/3]
#
# bestTest = 0.6590109663
# bestIteration = 30
#
# Training on fold [1/3]
#
# bestTest = 0.6324160287
# bestIteration = 7
#
# Training on fold [2/3]
#
# bestTest = 0.6712187047
# bestIteration = 6
#
# Elapsed time: 435.21 seconds
# {'depth': 10, 'l2_leaf_reg': 1, 'iterations': 50, 'learning_rate': 0.3}

# %%
fig = skplt.metrics.plot_calibration_curve(y_test, [y_proba], figsize=(10,6), clf_names=["catboost"])
plt.tight_layout()
plt.savefig('plots/step8_catboost_uncalibrated.png', dpi=300, bbox_inches='tight')
plt.show()

squared_error_uncalibrated = sum((fig.get_lines()[1].get_xdata() - fig.get_lines()[1].get_ydata())**2)

labels.append("CatBoost")
errors_uncalibrated.append(squared_error_uncalibrated)

# %%
test_model = CatBoostClassifier(early_stopping_rounds=20, eval_metric="AUC", verbose=0, cat_features=["chapter_ID"], **grid_search_result["params"])
calibrated_clf = CalibratedClassifierCV(base_estimator=test_model, cv=3, method="sigmoid")

calibrated_clf.fit(X_train_cat, y_train)

y_pred = calibrated_clf.predict(X_test_cat)
y_proba = calibrated_clf.predict_proba(X_test_cat)

fig = skplt.metrics.plot_calibration_curve(y_test, [y_proba], figsize=(12,7), clf_names=["catboost"])

squared_error_sigmoid = sum((fig.get_lines()[1].get_xdata() - fig.get_lines()[1].get_ydata())**2)
errors_sigmoid.append(squared_error_sigmoid)
plt.show()

df_scores.loc["CatBoost_platt"] = [round(end - start, 2),
                                        accuracy_score(y_test, y_pred),
                                        precision_score(y_test, y_pred),
                                        recall_score(y_test, y_pred),
                                        f1_score(y_test, y_pred),
                                        roc_auc_score(y_test, y_proba[:,1])]

# %%
test_model = CatBoostClassifier(early_stopping_rounds=20, eval_metric="AUC", verbose=0, cat_features=["chapter_ID"], **grid_search_result["params"])
calibrated_clf = CalibratedClassifierCV(base_estimator=test_model, cv=3, method="isotonic")

calibrated_clf.fit(X_train_cat, y_train)

y_pred = calibrated_clf.predict(X_test_cat)
y_proba = calibrated_clf.predict_proba(X_test_cat)

fig = skplt.metrics.plot_calibration_curve(y_test, [y_proba], figsize=(12,7), clf_names=["cat"])

squared_error_isotonic = sum((fig.get_lines()[1].get_xdata() - fig.get_lines()[1].get_ydata())**2)
errors_isotonic.append(squared_error_isotonic)
plt.show()

df_scores.loc["CatBoost_isotonic"] = [round(end - start, 2),
                                        accuracy_score(y_test, y_pred),
                                        precision_score(y_test, y_pred),
                                        recall_score(y_test, y_pred),
                                        f1_score(y_test, y_pred),
                                        roc_auc_score(y_test, y_proba[:,1])]

# %% [markdown]
# ## Compare results

# %%
df_scores.sort_values("auc", ascending=False)
# Out:
#                               training_time [s]  accuracy  precision  \
# XGBoost_isotonic                         303.25  0.728929   0.593023
# XGBoost_platt                            303.25  0.731207   0.607595
# XGBoost                                  303.25  0.719818   0.750000
# logistic_regression_isotonic               2.04  0.726651   0.588235
# logistic_regression_platt                  2.04  0.726651   0.594937
# logistic_regression                        2.04  0.708428   1.000000
# random_forest_isotonic                    56.28  0.731207   0.626866
# random_forest_platt                       56.28  0.735763   0.623377
# random_forest                             56.28  0.722096   0.597015
# knn_isotonic                               1.86  0.703872   0.547170
# knn_platt                                  1.86  0.712984   0.600000
# AdaBoost                                   4.78  0.706150   0.534091
# AdaBoost_isotonic                          4.78  0.703872   0.530864
# AdaBoost_platt                             4.78  0.701595   0.529412
# CatBoost_platt                           435.21  0.706150   0.588235
# CatBoost_isotonic                        435.21  0.710706   0.605263
# naive_bayes_isotonic                       2.04  0.722096   0.606557
# knn                                        1.86  0.701595   0.529412
# naive_bayes_platt                          2.04  0.692483   0.000000
# naive_bayes                                0.00  0.435080   0.331343
# decision_tree_isotonic                     4.33  0.717540   0.582090
# decision_tree_platt                        4.33  0.722096   0.606557
# decision_tree                              4.33  0.717540   0.617021
# CatBoost                                 435.21  0.703872   0.530120
#
#                                 recall        f1       auc
# XGBoost_isotonic              0.377778  0.461538  0.711087
# XGBoost_platt                 0.355556  0.448598  0.710063
# XGBoost                       0.133333  0.226415  0.707286
# logistic_regression_isotonic  0.370370  0.454545  0.704167
# logistic_regression_platt     0.348148  0.439252  0.702656
# logistic_regression           0.051852  0.098592  0.702266
# random_forest_isotonic        0.311111  0.415842  0.701937
# random_forest_platt           0.355556  0.452830  0.699050
# random_forest                 0.296296  0.396040  0.697368
# knn_isotonic                  0.214815  0.308511  0.683126
# knn_platt                     0.200000  0.300000  0.682943
# AdaBoost                      0.348148  0.421525  0.680068
# AdaBoost_isotonic             0.318519  0.398148  0.672844
# AdaBoost_platt                0.266667  0.354680  0.671126
# CatBoost_platt                0.148148  0.236686  0.669883
# CatBoost_isotonic             0.170370  0.265896  0.667495
# naive_bayes_isotonic          0.274074  0.377551  0.665156
# knn                           0.266667  0.354680  0.660916
# naive_bayes_platt             0.000000  0.000000  0.659211
# naive_bayes                   0.822222  0.472340  0.656871
# decision_tree_isotonic        0.288889  0.386139  0.652522
# decision_tree_platt           0.274074  0.377551  0.651840
# decision_tree                 0.214815  0.318681  0.649366
# CatBoost                      0.325926  0.403670  0.635819

# %%
df_scores.to_csv("model_scores_step8.csv")

# %% [markdown]
# ## Plot calibration error

# %%
x = np.arange(len(labels))  # the label locations
width = 0.28  # the width of the bars

fig, ax = plt.subplots(figsize=(14,6))
rects1 = ax.bar(x - width, errors_uncalibrated, width, color="tab:blue", edgecolor="k", label='Uncalibrated')
rects2 = ax.bar(x, errors_sigmoid, width, color="tab:green", edgecolor="k", label='Platt Scaling')
rects3 = ax.bar(x + width, errors_isotonic, width, color="tab:orange", edgecolor="k", label='Isotonic Regression')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Squared error')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate(f'{height:.2f}',
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)
autolabel(rects3)

fig.tight_layout()
plt.savefig('plots/step8_calibration_errors.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Plot AUC change

# %%
df_scores_auc = df_scores.copy()
df_scores_auc["calibration"] = "none"
df_scores_auc.loc[df_scores_auc.index.str.endswith("_platt"), "calibration"] = "platt"
df_scores_auc.loc[df_scores_auc.index.str.endswith("_isotonic"), "calibration"] = "isotonic"
df_scores_auc.index = df_scores_auc.index.str.replace("_platt", "", regex=False)
df_scores_auc.index = df_scores_auc.index.str.replace("_isotonic", "", regex=False)

auc_uncalibrated = df_scores_auc.loc[df_scores_auc["calibration"] == "none", "auc"].copy()
auc_platt = df_scores_auc.loc[df_scores_auc["calibration"] == "platt", "auc"].copy()
auc_isotonic = df_scores_auc.loc[df_scores_auc["calibration"] == "isotonic", "auc"].copy()
auc_uncalibrated = auc_uncalibrated.reindex(auc_platt.index)
# print(labels)
# print(auc_uncalibrated.index)
# print(auc_platt.index)
# print(auc_isotonic.index)

# %%
x = np.arange(len(labels))  # the label locations
width = 0.28  # the width of the bars

fig, ax = plt.subplots(figsize=(14,6))
rects1 = ax.bar(x - width, auc_uncalibrated, width, color="tab:blue", edgecolor="k", label='Uncalibrated')
rects2 = ax.bar(x, auc_platt, width, color="tab:green", edgecolor="k", label='Platt Scaling')
rects3 = ax.bar(x + width, auc_isotonic, width, color="tab:orange", edgecolor="k", label='Isotonic Regression')


# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('AUC')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate(f'{height:.3f}',
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)
autolabel(rects3)

fig.tight_layout()
plt.ylim([0, 0.85])

plt.savefig('plots/step8_calibration_auc.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Learning Curves

# %%
def prep_data(X_train, X_val, y_train, y_val, X_features_list):
    under_sampler = TomekLinks()
    X_resampled, y_resampled = under_sampler.fit_resample(X_train, y_train)

    scaler = StandardScaler()
    scaler.fit(X_resampled)
    X_train_final = pd.DataFrame(scaler.transform(X_resampled), columns=X_train.columns)
    X_val_final = pd.DataFrame(scaler.transform(X_val), columns=X_train.columns)

    X_train_final = X_train_final[X_features_list].copy()
    X_val_final = X_val_final[X_features_list].copy()
    
    return X_train_final, X_val_final, y_resampled, y_val

def plot_learning_curves(model, df, X_features_list):
    X = df.drop(["wont_renew", "chapter_ID"], axis=1).copy()
    y = df["wont_renew"].copy()
    
    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=710)
    train_errors, val_errors = [], []

    for m in range(100, len(X_train), 100):
        X_train_iter, X_val_iter, y_train_iter, y_val_iter = prep_data(X_train[:m], X_val, y_train[:m], y_val, X_features_list)

        model.fit(X_train_iter, y_train_iter)
        y_train_proba = model.predict_proba(X_train_iter)
        y_val_proba = model.predict_proba(X_val_iter)
        train_errors.append(roc_auc_score(y_train_iter, y_train_proba[:,1]))
        val_errors.append(roc_auc_score(y_val_iter, y_val_proba[:,1]))
    plt.plot(list(range(100, len(X_train), 100)), train_errors, linestyle="-", linewidth=2, color="tab:orange", label="train")
    plt.plot(list(range(100, len(X_train), 100)), val_errors, linestyle="-", linewidth=2, color="tab:blue", label="val")
    plt.xticks([x for x in range(100, len(X_train), 100)])
    plt.xlabel("Number of training samples")
    plt.ylabel("AUC")
    plt.legend()
    return train_errors[-1] - val_errors[-1]

# %% [markdown]
# ## Learning Curves

# %%
plt.figure(figsize=(14,6))
test_model = xgb.XGBClassifier(objective='binary:logistic', eval_metric="auc", random_state=42, use_label_encoder=False, **xg_cv.best_params_)
XGBoost_error = plot_learning_curves(test_model, df, xgb_10_features)
print(XGBoost_error)
plt.ylim([0.65, 1.01])
plt.savefig('plots/step9_learning_XGBoost.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# 0.028545072026051943

# %%
plt.figure(figsize=(14,6))
test_model = LogisticRegression(max_iter=5000, **logreg_cv.best_params_)
Logreg_error = plot_learning_curves(test_model, df, logreg_10_features)
print(Logreg_error)
plt.ylim([0.65, 1.01])
plt.savefig('plots/step9_learning_Logreg.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# 0.004113556072378288

# %%
plt.figure(figsize=(14,6))
test_model = RandomForestClassifier(**rf_cv.best_params_)
RF_error = plot_learning_curves(test_model, df, rf_10_features)
print(RF_error)
plt.ylim([0.65, 1.01])
plt.savefig('plots/step9_learning_RF.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# 0.08766853912920691
